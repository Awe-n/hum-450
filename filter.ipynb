# %%
## open the file 1855.xlsx
## read the first sheet

import pandas as pd

excel_name = '1835_v2.xlsx'

df = pd.read_excel(excel_name, sheet_name=0)

## print the first 5 rows

df.head()
# Out:
#    ID number  ID number corr  Page erreur_ligne  \
# 0        1.0               1     1          non
# 1        2.0               2     1          non
# 2        3.0               3     1          non
# 3        4.0               4     1          non
# 4        5.0               5     1          non
#
#                             division    nom_rue nom_rue_line _corr.   \
# 0  Marthery, St Pierre et Etraz // 1  martherey                  NaN
# 1                                  .          ·                  NaN
# 2                                  .          ·                  NaN
# 3                                  .          ·                  NaN
# 4                                  .          ·                  NaN
#
#   nom_rue_htr_corr nom_rue_norm no_maison  ... pensionnaires_condition  \
# 0        martherey    Martherey         1  ...        pensre friere se
# 1                .            .         ·  ...                  pensre
# 2                .            .         ·  ...                 ouvrier
# 3                .            .         ·  ...                  penvre
# 4                .            .         2  ...               ouvr|ouvr
#
#   pensionnaires_condition_line_corr2 pensionnaires_vocation_htr_corr  \
# 0                   pensre friere se           pen. Vve frère du dit
# 1                             pensre                         pens^tn
# 2                            ouvrier                         ouvrier
# 3                             penvre                         pens^tn
# 4                          ouvr|ouvr              ouvrier | ouvrier
#
#     pensionnaires_vocation_norm pensionnaires_vocation_remarque  \
# 0  pension veuve frère du dit ?                               .
# 1                  pensionnaire                               .
# 2                       ouvrier                               .
# 3                  pensionnaire                               .
# 4            ouvrier | ouvrier                                .
#
#   pensionnaires_recepisse pensionnaires_recepisse_line_corr observations  \
# 0                       ·                               NaN            ·
# 1                    4749                               NaN            ·
# 2                       ·                               NaN            ·
# 3                    5644                               NaN            ·
# 4              5850|17767                               NaN            ·
#
#   observations_line_corr observation_htr_corr
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
#
# [5 rows x 73 columns]

# %%
## print the column names of the dataframe
df.columns

## save in the variable 'useful_columns' the columns that contain the word 'pensionnaires'
useful_columns = [col for col in df.columns if 'pensionnaires' in col]

## print the useful columns
useful_columns
# Out:
# ['pensionnaires_prenom',
#  'pensionnaires_prenom_line_Corr',
#  'pensionnaires_nom',
#  'pensionnaires_nom_line_corr',
#  'pensionnaires_nom_htr_corr',
#  'pensionnaires_nom_norm',
#  'pensionnaires_nom_remarques',
#  'pensionnaires_origine',
#  'pensionnaires_origine_line_corr',
#  'pensionnaires_origine_htr_corr',
#  'pensionnaires_origine_norm',
#  'pensionnaires_origine_remarques',
#  'pensionnaires_condition',
#  'pensionnaires_condition_line_corr2',
#  'pensionnaires_vocation_htr_corr',
#  'pensionnaires_vocation_norm',
#  'pensionnaires_vocation_remarque',
#  'pensionnaires_recepisse',
#  'pensionnaires_recepisse_line_corr']

# %%
## create a new dataframe with only the useful columns
df2 = df[useful_columns]

## print the first 5 rows of the new dataframe
df2.head()
# Out:
#   pensionnaires_prenom pensionnaires_prenom_line_Corr pensionnaires_nom  \
# 0         george louis                            NaN            favrat
# 1             marc ant                            NaN            buffat
# 2                 marc                            NaN           strudel
# 3          susanne hte                            NaN           dutruit
# 4         louis|joseph                            NaN     pichard|modou
#
#   pensionnaires_nom_line_corr pensionnaires_nom_htr_corr  \
# 0                         NaN                     Favrat
# 1                         NaN                     Buffat
# 2                         NaN                    Strudel
# 3                         NaN                    Dutruit
# 4                         NaN            Pichard | Modou
#
#   pensionnaires_nom_norm pensionnaires_nom_remarques  \
# 0                 Favrat                           .
# 1                 Buffat                           .
# 2                Strudel                           .
# 3                Dutruit                           .
# 4        Pichard | Modou                           .
#
#          pensionnaires_origine pensionnaires_origine_line_corr  \
# 0                     lausanne                             NaN
# 1                      aubonne                             NaN
# 2                      belmont                             NaN
# 3                       perroy                             NaN
# 4  ormont dessus|cant fribourg                             NaN
#
#    pensionnaires_origine_htr_corr         pensionnaires_origine_norm  \
# 0                        Lausanne                           Lausanne
# 1                         Aubonne                            Aubonne
# 2                         Belmont                            Belmont
# 3                          Perroy                             Perroy
# 4  Ormont dessus | cant. fribourg  Ormont-dessus | Fribourg (canton)
#
#   pensionnaires_origine_remarques pensionnaires_condition  \
# 0                               .        pensre friere se
# 1                               .                  pensre
# 2                               .                 ouvrier
# 3                               .                  penvre
# 4                               .               ouvr|ouvr
#
#   pensionnaires_condition_line_corr2 pensionnaires_vocation_htr_corr  \
# 0                   pensre friere se           pen. Vve frère du dit
# 1                             pensre                         pens^tn
# 2                            ouvrier                         ouvrier
# 3                             penvre                         pens^tn
# 4                          ouvr|ouvr              ouvrier | ouvrier
#
#     pensionnaires_vocation_norm pensionnaires_vocation_remarque  \
# 0  pension veuve frère du dit ?                               .
# 1                  pensionnaire                               .
# 2                       ouvrier                               .
# 3                  pensionnaire                               .
# 4            ouvrier | ouvrier                                .
#
#   pensionnaires_recepisse pensionnaires_recepisse_line_corr
# 0                       ·                               NaN
# 1                    4749                               NaN
# 2                       ·                               NaN
# 3                    5644                               NaN
# 4              5850|17767                               NaN

# %%
## print the value of the first row for each column
df2.iloc[0]

## print only the value
df2.iloc[0].values

## filter the dataframe to keep only the rows that contain a value in the first column or the second column that is not '·'
df3 = df2[(df2.iloc[:,0] != '·') | (df2.iloc[:,1] != '·')]

## filter the dataframe df2 to keep only the rows that contain a value in the first column or the second column or the third column or the fourth column that is not '·'
df4 = df2[(df2.iloc[:,0] != '·') | (df2.iloc[:,1] != '·') | (df2.iloc[:,2] != '·') | (df2.iloc[:,3] != '·')]

# %%
## print the first 5 rows of the new dataframe
df4.head()
# Out:
#   pensionnaires_prenom pensionnaires_prenom_line_Corr pensionnaires_nom  \
# 0         george louis                            NaN            favrat
# 1             marc ant                            NaN            buffat
# 2                 marc                            NaN           strudel
# 3          susanne hte                            NaN           dutruit
# 4         louis|joseph                            NaN     pichard|modou
#
#   pensionnaires_nom_line_corr pensionnaires_nom_htr_corr  \
# 0                         NaN                     Favrat
# 1                         NaN                     Buffat
# 2                         NaN                    Strudel
# 3                         NaN                    Dutruit
# 4                         NaN            Pichard | Modou
#
#   pensionnaires_nom_norm pensionnaires_nom_remarques  \
# 0                 Favrat                           .
# 1                 Buffat                           .
# 2                Strudel                           .
# 3                Dutruit                           .
# 4        Pichard | Modou                           .
#
#          pensionnaires_origine pensionnaires_origine_line_corr  \
# 0                     lausanne                             NaN
# 1                      aubonne                             NaN
# 2                      belmont                             NaN
# 3                       perroy                             NaN
# 4  ormont dessus|cant fribourg                             NaN
#
#    pensionnaires_origine_htr_corr         pensionnaires_origine_norm  \
# 0                        Lausanne                           Lausanne
# 1                         Aubonne                            Aubonne
# 2                         Belmont                            Belmont
# 3                          Perroy                             Perroy
# 4  Ormont dessus | cant. fribourg  Ormont-dessus | Fribourg (canton)
#
#   pensionnaires_origine_remarques pensionnaires_condition  \
# 0                               .        pensre friere se
# 1                               .                  pensre
# 2                               .                 ouvrier
# 3                               .                  penvre
# 4                               .               ouvr|ouvr
#
#   pensionnaires_condition_line_corr2 pensionnaires_vocation_htr_corr  \
# 0                   pensre friere se           pen. Vve frère du dit
# 1                             pensre                         pens^tn
# 2                            ouvrier                         ouvrier
# 3                             penvre                         pens^tn
# 4                          ouvr|ouvr              ouvrier | ouvrier
#
#     pensionnaires_vocation_norm pensionnaires_vocation_remarque  \
# 0  pension veuve frère du dit ?                               .
# 1                  pensionnaire                               .
# 2                       ouvrier                               .
# 3                  pensionnaire                               .
# 4            ouvrier | ouvrier                                .
#
#   pensionnaires_recepisse pensionnaires_recepisse_line_corr
# 0                       ·                               NaN
# 1                    4749                               NaN
# 2                       ·                               NaN
# 3                    5644                               NaN
# 4              5850|17767                               NaN

# %%
## count the number of rows in the dataframe
df4.shape[0]
# Out:
# 3867

# %%
## export the dataframe to a xlsx file, with the previous name concatenated with '_filtered'
df4.to_excel(excel_name[:-5] + '_filtered.xlsx', index=False)

# %% [markdown]
# ## Check all useful columns in the dataset

# %%
## print the length of the useful columns
len(useful_columns)

## create a new dataframe with only the useful columns
## df4 filtered with the condition that the value of the first four columns is not '·' 
## df5 filtered with the condition that the value of the first len(useful_columns) columns is not '·' nor empty
df5 = df2[df4.iloc[:,:len(useful_columns)].notnull().all(axis=1)]

# %%
## print the first 5 rows of the new dataframe
df5.head()
# Out:
#                                   pensionnaires_prenom  \
# 52   nanelte|ent|isaac|jeannette|judith|jne se|loui...
# 53                                                   ·
# 66   die|benjamin|jeannette|dame|dame|antf et sa fe...
# 245                                              amram
# 246                                             margte
#
#                         pensionnaires_prenom_line_Corr  \
# 52   nanelte|ent|isaac|jeannette|judith|jne se|loui...
# 53                                         louise chte
# 66                                                 die
# 245                                                  .
# 246                                     amram | margte
#
#                                      pensionnaires_nom  \
# 52   girardet|coeylaux|gay|cretenoud|girardet|kurze...
# 53                                                   ·
# 66   schmid|roulet|guex|pelet|marguethaler|yersin|p...
# 245                                               guex
# 246                                            porchet
#
#                            pensionnaires_nom_line_corr  \
# 52   girardet|coeylaux|gay|cretenoud|girardet|kurze...
# 53                                              viller
# 66                                              schmid
# 245                                                  .
# 246                                     guex | porchet
#
#                             pensionnaires_nom_htr_corr  \
# 52   Girardet | Coeytaux | Gay | Cretenoud | Girard...
# 53                                              Viller
# 66                                             Schmidt
# 245                                                  .
# 246                                     Guex | Porchet
#
#                                 pensionnaires_nom_norm  \
# 52   Girardet | Coeytaux | Gay | Cretenoud | Girard...
# 53                                              Viller
# 66                                             Schmidt
# 245                                                  .
# 246                                     Guex | Porchet
#
#     pensionnaires_nom_remarques  \
# 52                            .
# 53                            .
# 66                            .
# 245                           .
# 246                           .
#
#                                  pensionnaires_origine  \
# 52   prilly|daillens|eperlines|renens|prilly|cant b...
# 53                                                   ·
# 66   nstate|mify|geneve|id|tolochenat|rougemont|orm...
# 245                                          jn legier
# 246                                           coralles
#
#                        pensionnaires_origine_line_corr  \
# 52   prilly|daillens|eperlines|renens|prilly|cant b...
# 53                                           thurgovie
# 66                                              nstate
# 245                                                  .
# 246                                jn legier  coralles
#
#                         pensionnaires_origine_htr_corr  \
# 52   Prilly | Daillens | Eperlines | Renens | Prill...
# 53                                           Thurgovie
# 66                                           Neustaler
# 245                                                  .
# 246                               St Légier | Coralles
#
#                             pensionnaires_origine_norm  \
# 52   Prilly | Daillens | Eperlines | Renens | Prill...
# 53                                           Thurgovie
# 66                                         Neustaler ?
# 245                                                  .
# 246                 Saint-Légier-La Chiésaz | Coralles
#
#     pensionnaires_origine_remarques  \
# 52                                .
# 53                                .
# 66                                .
# 245                               .
# 246                               .
#
#                                pensionnaires_condition  \
# 52   cuisiniere|employe|id|id|id|id|boulanger|infs|...
# 53                                                   ·
# 66   pension|cuisinier|cuisiniere|matresse|id|porti...
# 245                                             commis
# 246                                               pdon
#
#                 pensionnaires_condition_line_corr2  \
# 52   cuisiniere|employe|id|id|id|id|boulanger|infs
# 53                                          pensre
# 66                                         pension
# 245                                              .
# 246                                  commis | pdon
#
#                        pensionnaires_vocation_htr_corr  \
# 52   cuisinière | employé | employé | employé | emp...
# 53                                             pens^tn
# 66                                         pension^tre
# 245                                                  .
# 246                                       commis | dom
#
#                            pensionnaires_vocation_norm  \
# 52   cuisinière | employé | employé | employé | emp...
# 53                                        pensionnaire
# 66                                        pensionnaire
# 245                                                  .
# 246                                commis | domestique
#
#     pensionnaires_vocation_remarque  \
# 52                                .
# 53                                .
# 66                                .
# 245                               .
# 246                               .
#
#                                pensionnaires_recepisse  \
# 52                 4644|3465|3451|4597|4643|14952|5304
# 53                                                   ·
# 66   1722|2317|3451|336|·|1743|3339|·|4737|3206|·|1...
# 245                                               5063
# 246                                                  ·
#
#     pensionnaires_recepisse_line_corr
# 52     4644|3465|3451|4597|4643|14952
# 53                               5304
# 66                               1722
# 245                                 .
# 246                              5063

# %%
## save the dataframe in a xlsx file
df5.to_excel(excel_name[:-5] + '_filtered2.xlsx', index=False)

# %%
## get the id of all the rows that are in df5
useful_rows = df5.index

## use the id to filter the original dataframe, df
df6 = df.iloc[useful_rows]

## print the first 5 rows of the new dataframe
df6.head()
# Out:
#      ID number  ID number corr  Page erreur_ligne division        nom_rue  \
# 52        57.0              53     3          oui        .  chanx de lair
# 53        58.0              54     3          oui        .         bugnon
# 66        71.0              67     4          oui        .      martheres
# 245      253.0             246    10          oui        .          etraz
# 246      254.0             247    10          oui        .              ·
#
#     nom_rue_line _corr.  nom_rue_htr_corr nom_rue_norm no_maison  ...  \
# 52                   NaN   Champ de l'air       Bugnon        19  ...
# 53                   NaN           Bugnon       Bugnon         ·  ...
# 66                   NaN        martherey    Martherey       921  ...
# 245                  NaN            etraz        Étraz         1  ...
# 246                  NaN                .            .         ·  ...
#
#                                pensionnaires_condition  \
# 52   cuisiniere|employe|id|id|id|id|boulanger|infs|...
# 53                                                   ·
# 66   pension|cuisinier|cuisiniere|matresse|id|porti...
# 245                                             commis
# 246                                               pdon
#
#                 pensionnaires_condition_line_corr2  \
# 52   cuisiniere|employe|id|id|id|id|boulanger|infs
# 53                                          pensre
# 66                                         pension
# 245                                              .
# 246                                  commis | pdon
#
#                        pensionnaires_vocation_htr_corr  \
# 52   cuisinière | employé | employé | employé | emp...
# 53                                             pens^tn
# 66                                         pension^tre
# 245                                                  .
# 246                                       commis | dom
#
#                            pensionnaires_vocation_norm  \
# 52   cuisinière | employé | employé | employé | emp...
# 53                                        pensionnaire
# 66                                        pensionnaire
# 245                                                  .
# 246                                commis | domestique
#
#     pensionnaires_vocation_remarque  \
# 52                                .
# 53                                .
# 66                                .
# 245                               .
# 246                               .
#
#                                pensionnaires_recepisse  \
# 52                 4644|3465|3451|4597|4643|14952|5304
# 53                                                   ·
# 66   1722|2317|3451|336|·|1743|3339|·|4737|3206|·|1...
# 245                                               5063
# 246                                                  ·
#
#     pensionnaires_recepisse_line_corr  \
# 52     4644|3465|3451|4597|4643|14952
# 53                               5304
# 66                               1722
# 245                                 .
# 246                              5063
#
#                                           observations observations_line_corr  \
# 52                                                   ·                    NaN
# 53                                                   ·                    NaN
# 66   ·|id|id|·|·|·|·|·|·|·|·|·|·|·|·|·|·|parens en ...                      ·
# 245                                                  ·                    NaN
# 246                                                  ·                    NaN
#
#     observation_htr_corr
# 52                   NaN
# 53                   NaN
# 66                   NaN
# 245                  NaN
# 246                  NaN
#
# [5 rows x 73 columns]

# %%
## save the dataframe in a xlsx file
df6.to_excel(excel_name[:-5] + '_filtered-full.xlsx', index=False)
